# %%
from sklearn.datasets import load_iris, load_diabetes

data = load_iris(as_frame=True)

X = data.data
y = data.target
target_names = data.target_names

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((100, 4), (50, 4))

# %%
#för att se så att datan delade upp sig bra, nu har jag 35 av en grupp, 34 av en annan grupp och 31 av en annan grupp.
# Dubbel kollar så att man inte har all data av samma grupp i test sen, men som vi ser är det jämt fördelat

y_train.value_counts()
# Out:
# target
# 1    35
# 2    34
# 0    31
# Name: count, dtype: int64
